// %% [markdown]
// # Εισαγωγή στον προγραμματισμό με τη γλώσσα Java
// © Γιάννης Κωστάρας
//
// ---
//
// [![Mathesis](../assets/mathesis.png)](http://mathesis.cup.gr)
//
// ## Πίνακας περιεχομένων
// ### Εβδομάδα 1η - Εισαγωγή
// 1. [Εισαγωγή στους Η/Υ](Week1/1.1-Introduction/1.1-Introduction.ipynb)
// 2. [Αλγόριθμοι και Προγράμματα](Week1/1.2-Algorithm/1.2-Algorithm.ipynb)
// 3. [Ιστορία της γλώσσας προγραμματισμού Java](Week1/1.3-JavaHistory/1.3-JavaHistory.ipynb)
// 4. [Εγκατάσταση της Java](Week1/1.4-Installation/1.4-Installation.ipynb)
// 5. [Εισαγωγή στη γλώσσα προγραμματισμού Java](Week1/1.5-JavaBasics/1.5-JavaBasics.ipynb)
// 6. [Αριθμοί, μεταβλητές, εκφράσεις](Week1/1.6-JavaBasics/1.6-JavaBasics.ipynb)
// 7. [Συμβολοσειρές (Strings)](Week1/1.7-Strings/1.7-Strings.ipynb)
//
// ### Εβδομάδα 2η - Εντολές αποφάσεων, εντολές επανάληψης, συστοιχίες και μέθοδοι
// 1. [Εντολές Αποφάσεων](Week2/2.1-ControlStatements/2.1-ControlStatements.ipynb)
// 2. [Εντολές Επανάληψης (Loops)](Week2/2.2-Loops/2.2-Loops.ipynb)
// 3. [Πίνακες ή Συστοιχίες (Arrays)](Week2/2.3-Arrays/2.3-Arrays.ipynb)
// 4. [Μέθοδοι (Methods)](Week2/2.4-Methods/2.4-Methods.ipynb)
// 5. [Αναδρομικές Μέθοδοι (Recursive Methods)](Week2/2.5-RecursiveMethods/2.5-RecursiveMethods.ipynb)
// 6. [Δημιουργία του πρώτου μας προγράμματος Java σε ένα ΟΠΕ](Week2/2.6-IDEs/2.6-IDEs.ipynb)
// 7. [Αποσφαλμάτωση](Week2/2.7-Debugging/2.7-Debugging.ipynb)
//
// ### Εβδομάδα 3η - Αντικειμενοστραφής προγραμματισμός Ι
// 1. [Εισαγωγή στον Αντικειμενοστραφή Προγραμματισμό](Week3/3.1-OOP/3.1-OOP.ipynb)
// 2. [Δημιουργία κλάσεων στο ΟΠΕ](Week3/3.2-IDEs/3.2-IDEs.ipynb)
// 3. [Εισαγωγή στη UML](Week3/3.3-UML/3.3-UML.ipynb)
// 4. [Ιδιότητες του Αντικειμενοστραφούς Προγραμματισμού](Week3/3.4-OOProperties/3.4-OOProperties.ipynb)
// 5. [Ενθυλάκωση, Πακέτα και Αρθρώματα (Encapsulation, Packages and Modules)](Week3/3.5-Encapsulation/3.5-Encapsulation.ipynb)
// 6. [Άσκηση 1](Week3/3.6-Exercise1/3.6-Exercise1.ipynb)
// 7. [Άσκηση 2](Week3/3.7-Exercise1/3.7-Exercise2.ipynb)
//
// ### Εβδομάδα 4η - Αντικειμενοστραφής προγραμματισμός ΙΙ
// 1. [Κληρονομικότητα (Inheritance)](Week4/4.1-Inheritance/4.1-Inheritance.ipynb)
// 2. [Πολυμορφισμός (Polymorphism)](Week4/4.2-Polymorphism/4.2-Polymorphism.ipynb)
// 3. [Απαριθμημένοι Τύποι (Enums)](Week4/4.3-Enums/4.3-Enums.ipynb)
// 3. [Τεκμηρίωση κώδικα (Javadoc)](Week4/4.4-JavaDoc/4.4-JavaDoc.ipynb)
// 4. [Καλές τεχνικές προγραμματισμού](Week4/4.5-BestPractices/4.5-BestPractices.ipynb)
// 5. [Άσκηση Αντικειμενοστραφούς Προγραμματισμού](Week4/4.6-Exercise/4.6-Exercise.ipynb)
//
// ### Εβδομάδα 5η - Δομές Δεδομένων και Γενικευμένοι Τύποι (Generics)
// 1. [Δομές Δεδομένων (Data Structures)](Week5/5.1-DataStructures/5.1-DataStructures.ipynb)
// 2. [Γραμμικές Λίστες (Lists)](Week5/5.2-Lists/5.2-Lists.ipynb)
// 3. [Γενικευμένοι Τύποι (Generics)](Week5/5.3-Generics/5.3-Generics.ipynb)
// 4. [Σύνολα (Sets)](Week5/5.4-Sets/5.4-Sets.ipynb)
// 5. [Ουρές (Queues)](Week5/5.5-Queues/5.5-Queues.ipynb)
// 6. [Πίνακες κατακερματισμού (Maps)](Week5/5.6-Maps/5.6-Maps.ipynb)
// 7. [Άλλες Δομές Δεδομένων](Week5/5.7-OtherCollections/5.7-OtherCollections.ipynb)
// 8. [Άσκηση Αντικειμενοστραφούς Προγραμματισμού](Week5/5.8-Exercise/5.8-Exercise.ipynb)
//
// ### Εβδομάδα 6η - Εξαιρέσεις και Χρήσιμες Κλάσεις
// 1. [Εξαιρέσεις (Exceptions)](Week6/6.1-Exceptions/6.1-Exceptions.ipynb)
// 2. [Χρήσιμες κλάσεις](Week6/6.2-UsefulClasses/6.2-UsefulClasses.ipynb)
// 3. [Εργαλεία Οικοδόμισης Κώδικα (Build Tools)](Week6/6.3-BuildTools/6.3-BuildTools.ipynb)
// 4. [Διεθνοποίηση (Internationalisation)](Week6/6.4-I18n/6.4-I18n.ipynb)
// 5. [Αρχεία καταγραφής (Logging)](Week6/6.5-Logging/6.5-Logging)
// 6. [Έλεγχος Ποιότητας κώδικα (Unit Testing)](Week6/6.6-UnitTesting/6.6-UnitTesting.ipynb)
// 7. [Άσκηση Αντικειμενοστραφούς Προγραμματισμού](Week6/6.7-Exercise/6.7-Exercise.ipynb)
//
//
//
// ---
